# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import imageio

# %%
image = imageio.imread("C:/Users/oekpom/Desktop/Datasets/Machine Learning/Lesson 7-Unsupervised Learning/tiger.png")
plt.figure(figsize = (15,8))
plt.imshow(image)

# %%
image.shape
# Out:
# (720, 1280, 3)

# %%
x, y, z = image.shape
image_2d = image.reshape(x*y, z)
image_2d.shape
# Out:
# (921600, 3)

# %%
kmeans_cluster = KMeans(n_clusters=7)
kmeans_cluster.fit(image_2d)
cluster_centers = kmeans_cluster.cluster_centers_
cluster_labels = kmeans_cluster.labels_

# %%
import numpy as np
plt.figure(figsize = (15,8))
data = cluster_centers[cluster_labels].reshape(x, y, z)
image_8bit = np.uint8(data)
plt.imshow(image_8bit)
